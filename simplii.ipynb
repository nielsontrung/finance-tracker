# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import json
import glob
from datetime import datetime
from util import get_category

# %% [markdown]
# # Get CSV files

# %%
def read_simplii_files():
    # get statement folder path
    config = open("./config.json").read()
    folder_path = json.loads(config).get("simplii").get("folderPath")
    csv_files = glob.glob(f"{folder_path}/*.csv")
    dfs = {}
    combined_df = pd.DataFrame()
    for csv_file in csv_files:
        print(csv_file)
        df = pd.read_csv(
            csv_file,
            index_col=False,
        )
        if len(df.columns) == 5:
            df = df.set_axis(
                ["Date", "Transaction Details", "Funds Out", "Funds In", "Account"],
                axis=1,
            )
        else:
            df = df.set_axis(
                ["Date", "Transaction Details", "Funds Out", "Funds In"], axis=1
            )
            df["Credit Account"] = "*" * 16
        if "visa" in csv_file.lower():
            df = df[~df["Funds In"].notnull()]
        df["sourceFile"] = csv_file
        dfs[csv_file] = df
        combined_df = pd.concat([combined_df, df])
    combined_df = combined_df.replace({np.nan: None})
    combined_df[["Month", "Day", "Year"]] = combined_df["Date"].str.split(
        "/", expand=True
    )
    combined_df["Category"] = combined_df["Transaction Details"].apply(
        lambda x: get_category(x.lower())
    )
    combined_df["Points"] = 0
    combined_df = combined_df[
        [
            "Account",
            "Date",
            "Month",
            "Day",
            "Year",
            "Category",
            "Transaction Details",
            "Funds In",
            "Funds Out",
            "Points",
            "sourceFile",
        ]
    ]
    return combined_df

# %%
combined_df = read_simplii_files()
combined_df.head()
# Out:
# C:\Users\Nielson\Documents\Statements\simplii\SIMPLII_chequeing.csv
# C:\Users\Nielson\Documents\Statements\simplii\SIMPLII_visa.csv
#   Account        Date Month Day  Year   Category  \
# 0    None  05/15/2024    05  15  2024  Transfers
# 1    None  05/15/2024    05  15  2024  Transfers
# 2    None  05/29/2024    05  29  2024  Transfers
# 3    None  06/03/2024    06  03  2024  Transfers
# 4    None  06/03/2024    06  03  2024  Transfers
#
#                               Transaction Details Funds In Funds Out  Points  \
# 0        INTERAC E-TRANSFER RECEIVE NIELSON TRUNG     10.0      None       0
# 1        INTERAC E-TRANSFER RECEIVE NIELSON TRUNG   1000.0      None       0
# 2     INTERAC E-TRANSFER RECEIVE SHAHANAH LIGARAY     22.0      None       0
# 3            INTERAC E-TRANSFER RECEIVE RYAN PANG     28.0      None       0
# 4   INTERAC E-TRANSFER RECEIVE WESLEY TZE FAH LAI     30.0      None       0
#
#                                           sourceFile
# 0  C:\Users\Nielson\Documents\Statements\simplii\...
# 1  C:\Users\Nielson\Documents\Statements\simplii\...
# 2  C:\Users\Nielson\Documents\Statements\simplii\...
# 3  C:\Users\Nielson\Documents\Statements\simplii\...
# 4  C:\Users\Nielson\Documents\Statements\simplii\...

# %% [markdown]
# # Funds In & Out per Month

# %%
groupby_df = (
    combined_df[["Year", "Month", "Funds In", "Funds Out"]]
    .groupby(["Year", "Month"])
    .sum()
)
groupby_df
# Out:
#            Funds In Funds Out
# Year Month
# 2024 05      1032.0     54.28
#      06     4365.52    471.15
#      07     4473.03   5553.34
#      08      2624.0   2602.58

# %% [markdown]
# # Get Monthly Spending per Category

# %%
# combined_df[combined_df["Category"] == "Restaurant"][["Year","Month","Funds Out", "Funds In", "Category"]].groupby(["Year","Month","Category"]).sum()
combined_df[["Year", "Month", "Funds In", "Funds Out", "Category"]].groupby(
    ["Year", "Month", "Category"]
).sum().sort_values(["Year", "Month", "Category"], ascending=True)
# Out:
#                       Funds In Funds Out
# Year Month Category
# 2024 05    Restaurant        0     54.28
#            Transfers    1032.0         0
#      06    Deposit      4210.0         0
#            Groceries         0     92.93
#            Other          0.02     51.39
#            Restaurant        0    326.83
#            Transfers     155.5         0
#      07    Deposit     4209.99         0
#            Investment        0    3100.0
#            Other          0.04         0
#            Payment           0   1478.15
#            Restaurant        0    416.32
#            Transfers     263.0    558.87
#      08    Deposit      2105.0         0
#            Investment        0     500.0
#            Payment           0   1560.24
#            Restaurant        0     42.34
#            Transfers     119.0     500.0
#            Withdrawal    400.0         0

# %%
sort_by_cols = ["Date", "Category", "Transaction Details"]
combined_df[
    combined_df["Funds Out"].notnull()
    & ~combined_df["Category"].isin(["Transfers", "Investment", "Deposit", "Payment"])
].sort_values(by=sort_by_cols, ascending=False)
# Out:
#              Account        Date Month Day  Year    Category  \
# 2   4525********3980  08/01/2024    08  01  2024  Restaurant
# 3   4525********3980  08/01/2024    08  01  2024  Restaurant
# 1   4525********3980  08/01/2024    08  01  2024  Restaurant
# 4   4525********3980  07/31/2024    07  31  2024  Restaurant
# 5   4525********3980  07/29/2024    07  29  2024  Restaurant
# 7   4525********3980  07/29/2024    07  29  2024  Restaurant
# 6   4525********3980  07/29/2024    07  29  2024  Restaurant
# 8   4525********3980  07/26/2024    07  26  2024  Restaurant
# 9   4525********3980  07/22/2024    07  22  2024  Restaurant
# 10  4525********3980  07/18/2024    07  18  2024  Restaurant
# 11  4525********3980  07/15/2024    07  15  2024  Restaurant
# 12  4525********3980  07/10/2024    07  10  2024  Restaurant
# 14  4525********3980  07/02/2024    07  02  2024  Restaurant
# 15  4525********3980  06/25/2024    06  25  2024  Restaurant
# 16  4525********3980  06/24/2024    06  24  2024       Other
# 17  4525********3980  06/20/2024    06  20  2024  Restaurant
# 18  4525********3980  06/20/2024    06  20  2024  Restaurant
# 19  4525********3980  06/18/2024    06  18  2024  Restaurant
# 20  4525********3980  06/17/2024    06  17  2024  Restaurant
# 21  4525********3980  06/14/2024    06  14  2024  Restaurant
# 22  4525********3980  06/10/2024    06  10  2024       Other
# 23  4525********3980  06/04/2024    06  04  2024   Groceries
# 24  4525********3980  06/03/2024    06  03  2024  Restaurant
# 25  4525********3980  05/30/2024    05  30  2024  Restaurant
#
#                       Transaction Details Funds In Funds Out  Points  \
# 2          SNOWY VILLAGE CAFE CALGARY, AB     None      8.93       0
# 3          SNOWY VILLAGE CAFE CALGARY, AB     None     13.39       0
# 1              Five Guys 1963 Calgary, AB     None     20.02       0
# 4               DONAIR PALACE CALGARY, AB     None     10.49       0
# 5             TSUJIRI CALGARY CALGARY, AB     None     17.04       0
# 7          MR. PRETZELS ROCKY VIEW CO, AB     None      5.76       0
# 6   HCM*KINJO DALHOUSIE K2 ST CALGARY, AB     None     41.14       0
# 8                  SAIGON REX CALGARY, AB     None     44.08       0
# 9       CHEONG DAM KOREAN BBQ CALGARY, AB     None    115.76       0
# 10         TIM HORTONS #20024 CALGARY, AB     None     20.13       0
# 11     SQ *REDHEADS JAPA CAFE Calgary, AB     None     54.49       0
# 12  HCM*KINJO DALHOUSIE K2 ST CALGARY, AB     None     57.55       0
# 14          U & ME RESTAURANT CALGARY, AB     None     49.88       0
# 15                  JUN KATSU CALGARY, AB     None      48.3       0
# 16     THE CHOPPED LEAF CL055 CALGARY, AB     None     16.78       0
# 17                HURRY CURRY CALGARY, AB     None     23.79       0
# 18   DAIRY QUEEN - SHAGANAPPI CALGARY, AB     None      13.1       0
# 19         DAIRY QUEEN #27120 CALGARY, AB     None     39.99       0
# 20                  JUN KATSU CALGARY, AB     None     72.45       0
# 21                  A&W #1480 CALGARY, AB     None     18.37       0
# 22     THE CHOPPED LEAF CL055 CALGARY, AB     None     34.61       0
# 23     MILESTONES MARKET MALL CALGARY, AB     None     92.93       0
# 24     SQ *REDHEADS JAPA CAFE Calgary, AB     None    110.83       0
# 25               TAKUMI SUSHI CALGARY, AB     None     54.28       0
#
#                                            sourceFile
# 2   C:\Users\Nielson\Documents\Statements\simplii\...
# 3   C:\Users\Nielson\Documents\Statements\simplii\...
# 1   C:\Users\Nielson\Documents\Statements\simplii\...
# 4   C:\Users\Nielson\Documents\Statements\simplii\...
# 5   C:\Users\Nielson\Documents\Statements\simplii\...
# 7   C:\Users\Nielson\Documents\Statements\simplii\...
# 6   C:\Users\Nielson\Documents\Statements\simplii\...
# 8   C:\Users\Nielson\Documents\Statements\simplii\...
# 9   C:\Users\Nielson\Documents\Statements\simplii\...
# 10  C:\Users\Nielson\Documents\Statements\simplii\...
# 11  C:\Users\Nielson\Documents\Statements\simplii\...
# 12  C:\Users\Nielson\Documents\Statements\simplii\...
# 14  C:\Users\Nielson\Documents\Statements\simplii\...
# 15  C:\Users\Nielson\Documents\Statements\simplii\...
# 16  C:\Users\Nielson\Documents\Statements\simplii\...
# 17  C:\Users\Nielson\Documents\Statements\simplii\...
# 18  C:\Users\Nielson\Documents\Statements\simplii\...
# 19  C:\Users\Nielson\Documents\Statements\simplii\...
# 20  C:\Users\Nielson\Documents\Statements\simplii\...
# 21  C:\Users\Nielson\Documents\Statements\simplii\...
# 22  C:\Users\Nielson\Documents\Statements\simplii\...
# 23  C:\Users\Nielson\Documents\Statements\simplii\...
# 24  C:\Users\Nielson\Documents\Statements\simplii\...
# 25  C:\Users\Nielson\Documents\Statements\simplii\...

# %% [markdown]
# # Payments Bills

# %%
combined_df[combined_df["Category"] == "Payment"][
    ["Year", "Month", "Category", "Funds In", "Funds Out"]
].groupby(["Year", "Month", "Category"]).sum()
# Out:
#                     Funds In Funds Out
# Year Month Category
# 2024 07    Payment         0   1478.15
#      08    Payment         0   1560.24

# %%
combined_df[combined_df["Category"] == "Payment"].sort_values(
    by=["Date"], ascending=False
)
# Out:
#    Account        Date Month Day  Year Category  \
# 30    None  08/02/2024    08  02  2024  Payment
# 26    None  07/31/2024    07  31  2024  Payment
# 22    None  07/19/2024    07  19  2024  Payment
# 15    None  07/05/2024    07  05  2024  Payment
# 13    None  07/04/2024    07  04  2024  Payment
#
#                                   Transaction Details Funds In Funds Out  \
# 30     MISCELLANEOUS PAYMENTS American Express CHEQUE     None   1560.24
# 26  MISCELLANEOUS PAYMENTS CIBC CARD PRODUCTS DIVI...     None    100.92
# 22               EFT DEBIT AMEX BANK OF CANADA CHEQUE     None   1000.42
# 15  MISCELLANEOUS PAYMENTS CIBC CARD PRODUCTS DIVI...     None    292.65
# 13  MISCELLANEOUS PAYMENTS CIBC CARD PRODUCTS DIVI...     None     84.16
#
#     Points                                         sourceFile
# 30       0  C:\Users\Nielson\Documents\Statements\simplii\...
# 26       0  C:\Users\Nielson\Documents\Statements\simplii\...
# 22       0  C:\Users\Nielson\Documents\Statements\simplii\...
# 15       0  C:\Users\Nielson\Documents\Statements\simplii\...
# 13       0  C:\Users\Nielson\Documents\Statements\simplii\...

# %%
def get_simplii_transactions():
    df = read_simplii_files()
    df = df[~df["description"].str.contains("PAYMENT")]
    df["amount"] = df["amount"].abs()
    df["amount"] *= -1
    df["foreignAmount"] = df["foreignAmount"].fillna(0)
    df["points"] = df["points"].fillna(0)
    df[["month", "day", "year"]] = df["date"].str.split("/", expand=True)
    df["date"] = df["year"] + "/" + df["month"] + "/" + df["day"]
    df["id"] = df["id"].str.replace("Reference: ", "")
    df["account"] = "simplii"
    df["description"] = df["description"].str.lower()
    df["description"] = df["description"].str.replace("-", "")
    df["category"] = df["description"].apply(get_category)
    df["sourceFile"] = input_file
    df = df.drop("foreignAmount", axis=1)
    columns = [
        "account",
        "date",
        "year",
        "month",
        "day",
        "category",
        "description",
        "amount",
        "points",
        "sourceFile",
    ]
    df = df[columns]
    transactions = df.values.tolist()
    return transactions
